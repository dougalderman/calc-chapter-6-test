# %%
#Problem 15

# %%
x = var('x')

# %%
y = var('y')

# %%
def f(x, y): return x - (1/2)*y^2 - (1/3)*x^3

# %%
plot3d(f,(x,-5,5),(y,-5,5),color='blue',opacity=0.8)
# Out:
# Graphics3d Object

# %%
def fx(x, y): return derivative(f(x, y), x)

# %%
fx(x, y)
# Out:
# -x^2 + 1

# %%
def fy(x, y): return derivative(f(x, y), y)

# %%
fy(x, y)
# Out:
# -y

# %%
fxx = derivative(f(x, y), x, 2)

# %%
fxx
# Out:
# -2*x

# %%
fyy = derivative(f(x, y), y, 2)

# %%
fyy
# Out:
# -1

# %%
fxy = derivative(fx(x, y), y)

# %%
fxy
# Out:
# 0

# %%
solve([fx(x, y)==0, fy(x, y)==0], x, y)
# Out:
# [[x == 1, y == 0], [x == -1, y == 0]]

# %%
def fxx(x, y): return -2*x

# %%
def fyy(x, y): return -1

# %%
def fxy(x, y): return 0

# %%
def D(x, y): return fxx(x, y)*fyy(x, y)-(fxy(x, y))^2

# %%
D(-1, 0)
# Out:
# -2

# %%
D(1, 0)
# Out:
# 2

# %%
fxx(1, 0)
# Out:
# -2

# %%
f(1, 0)
# Out:
# 2/3
